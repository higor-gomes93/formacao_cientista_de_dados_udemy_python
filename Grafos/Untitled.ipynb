# %%
import pandas as pd

# %%
lista = pd.read_csv(r"C:\Users\Usuario\Downloads\Controle Geral - I.Systems S.A. - Dados - Férias.csv")

# %%
lista['NOME']
# Out:
# 0                   Adriana Cardoso Yui
# 1                  Alex Rodrigues Kisch
# 2                  Alysson Dias Miranda
# 3             Amanda Moreira Castellini
# 4      Ana Clara Besson Vezzaro Izidoro
#                     ...
# 85                 Victor Santos Vieira
# 86           Wellington Alves das Neves
# 87            Wellington da Silva Gomes
# 88      William Eduardo Herrera Agudelo
# 89    William Roberto Ferreira da Silva
# Name: NOME, Length: 90, dtype: object

# %%
vetor = []
for i in range(len(lista)):
    vetor.append((lista['NOME_ID'][i], lista['LIDER_ID'][i]))
    
vetor
# Out:
# [(1, 84),
#  (2, 44),
#  (3, 84),
#  (4, 42),
#  (5, 67),
#  (6, 23),
#  (7, 86),
#  (8, 62),
#  (9, 19),
#  (10, 77),
#  (11, 18),
#  (12, 44),
#  (13, 18),
#  (14, 71),
#  (15, 27),
#  (16, 25),
#  (17, 84),
#  (18, 25),
#  (19, 25),
#  (20, 44),
#  (21, 71),
#  (22, 18),
#  (23, 77),
#  (24, 8),
#  (25, 41),
#  (26, 44),
#  (27, 84),
#  (28, 41),
#  (29, 41),
#  (30, 23),
#  (31, 19),
#  (32, 27),
#  (33, 17),
#  (34, 8),
#  (35, 18),
#  (36, 23),
#  (37, 67),
#  (38, 18),
#  (39, 42),
#  (40, 27),
#  (41, 41),
#  (42, 41),
#  (43, 18),
#  (44, 25),
#  (45, 84),
#  (46, 19),
#  (47, 44),
#  (48, 62),
#  (49, 39),
#  (50, 18),
#  (51, 19),
#  (52, 19),
#  (53, 71),
#  (54, 18),
#  (55, 29),
#  (56, 67),
#  (57, 79),
#  (58, 29),
#  (59, 67),
#  (60, 71),
#  (61, 19),
#  (62, 25),
#  (63, 44),
#  (64, 60),
#  (65, 23),
#  (66, 19),
#  (67, 41),
#  (68, 8),
#  (69, 41),
#  (70, 67),
#  (71, 41),
#  (72, 44),
#  (73, 8),
#  (74, 23),
#  (75, 18),
#  (76, 18),
#  (77, 41),
# ...

# %%
list(lista['NOME'])
# Out:
# ['Adriana Cardoso Yui',
#  'Alex Rodrigues Kisch',
#  'Alysson Dias Miranda',
#  'Amanda Moreira Castellini',
#  'Ana Clara Besson Vezzaro Izidoro',
#  'Ana Cláudia Oliveira e Souza',
#  'Ana Luiza Teixeira Serva',
#  'André de Moura Oliveira',
#  'André Moreira Pimentel',
#  'André Wilian Magalhaes Dutra',
#  'Anita Huang',
#  'Atila Lopes Gadelha',
#  'Beatriz Emanuella de Andrade Bressan',
#  'Brenda Braga de Queiroz',
#  'Breno dos Santos Costa',
#  'Bruna Mancuzo de Almeida',
#  'Bruno Monteiro Pires',
#  'Caio Oliveira Biondi',
#  'Camila De Lima Leal',
#  'Carla Freitas Amaral',
#  'Cecília de Jesus Aboboreira',
#  'Celso Gabriel Ruela',
#  'Cristina Célia Barros Cavalcante',
#  'Daniel Bacellar Souza Vozza',
#  'Danilo Lavigne Halla',
#  'Eduardo Alexsander Batista Vila Nova',
#  'Fabiana Cristina Vilela',
#  'Felipe Dreher',
#  'Felipe Varejão Pereira',
#  'Fernanda Bia Peteam',
#  'Fernanda Ripoli Martins',
#  'Gabriel da Gama Fiel Oliveira',
#  'Guilherme Alcarde Gallo',
# ...
